# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None 

# File to Load (Remember to Change These)
ds = "Data/new_global_dataset_2020.csv"

# Read Purchasing File and store into Pandas data frame
ds_df = pd.read_csv(ds)

ds_df.head()
# Out:
#    Unnamed: 0  yearOfRegistration Datasource  gender ageBroad majorityStatus  \
# 0       18733                2015    Hotline  Female   18--20          Adult
# 1       18734                2015    Hotline  Female   18--20          Adult
# 2       18735                2015    Hotline  Female   18--20          Adult
# 3       18736                2015    Hotline  Female   18--20          Adult
# 4       18737                2015    Hotline  Female   18--20          Adult
#
#   majorityStatusAtExploit citizenship  meansOfControlTakesEarnings  \
# 0                   Minor          US                          -99
# 1                   Adult          US                          -99
# 2                   Minor          US                          -99
# 3                     -99          US                          -99
# 4                     -99          US                          -99
#
#    meansOfControlThreats  ...  meansOfControlUsesChildren  \
# 0                    -99  ...                         -99
# 1                    -99  ...                         -99
# 2                      1  ...                         -99
# 3                    -99  ...                         -99
# 4                      1  ...                         -99
#
#    meansOfControlThreatOfLawEnforcement  isForcedLabour  isSexualExploit  \
# 0                                   -99               0                1
# 1                                   -99               0                1
# 2                                   -99               0                1
# 3                                   -99               0                1
# 4                                   -99               0                1
#
#    isOtherExploit  isAbduction  recruiterRelationIntimatePartner  \
# 0               0            0                                 1
# 1               0            0                               -99
# 2               0            0                                 0
# 3               0            0                                 1
# 4               0            0                                 1
#
#    recruiterRelationFriend  recruiterRelationFamily  recruiterRelationOther
# 0                        0                        0                       0
# 1                      -99                      -99                     -99
# 2                        1                        0                       0
# 3                        0                        0                       0
# 4                        0                        0                       0
#
# [5 rows x 25 columns]

# %%
import pandas as pd

# %%
data = pd.read_json("assault_us_array.json")

# %%
data
# Out:
#                                        _id  yearOfRegistration Datasource  \
# 0     {'$oid': '5f751810edbeb111ec3ccdcd'}                2015    Hotline
# 1     {'$oid': '5f751810edbeb111ec3ccdce'}                2015    Hotline
# 2     {'$oid': '5f751810edbeb111ec3ccdcf'}                2015    Hotline
# 3     {'$oid': '5f751810edbeb111ec3ccdd0'}                2015    Hotline
# 4     {'$oid': '5f751810edbeb111ec3ccdd1'}                2015    Hotline
# ...                                    ...                 ...        ...
# 3631  {'$oid': '5f751811edbeb111ec3cdbfc'}                2018    Hotline
# 3632  {'$oid': '5f751811edbeb111ec3cdbfd'}                2018    Hotline
# 3633  {'$oid': '5f751811edbeb111ec3cdbfe'}                2018    Hotline
# 3634  {'$oid': '5f751811edbeb111ec3cdbff'}                2018    Hotline
# 3635  {'$oid': '5f751811edbeb111ec3cdc00'}                2018    Hotline
#
#       gender ageBroad majorityStatus majorityStatusAtExploit citizenship  \
# ...

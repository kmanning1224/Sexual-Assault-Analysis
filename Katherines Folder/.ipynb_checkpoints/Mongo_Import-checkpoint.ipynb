# %%
import pandas as pd
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
#database
db = client["assault_db_us"]

# %%
#collection
collection = db["assault_us"]

# %%
data = pd.read_csv("new_global_dataset_2020.csv")

# %%
# Out:
#                         _id        yearOfRegistration Datasource  gender  \
# 0  5f751810edbeb111ec3ccdcd  18733               2015    Hotline  Female
# 1  5f751810edbeb111ec3ccdce  18734               2015    Hotline  Female
# 2  5f751810edbeb111ec3ccdcf  18735               2015    Hotline  Female
# 3  5f751810edbeb111ec3ccdd0  18736               2015    Hotline  Female
# 4  5f751810edbeb111ec3ccdd1  18737               2015    Hotline  Female
#
#   ageBroad majorityStatus majorityStatusAtExploit citizenship  \
# 0   18--20          Adult                   Minor          US
# 1   18--20          Adult                   Adult          US
# 2   18--20          Adult                   Minor          US
# 3   18--20          Adult                     -99          US
# 4   18--20          Adult                     -99          US
#
#   meansOfControlTakesEarnings  ... meansOfControlUsesChildren  \
# 0                         -99  ...                        -99
# ...

# %%
data.reset_index(inplace=True)
data_dict = data.to_dict("records")
collection.insert_one({"index":"ID", "data":data_dict})

# %%
#checking that information uploaded to MongoDB

# %%
db = client.assault_db_us
collection = db.assault_us

# %%
data = pd.DataFrame(list(collection.find()))

# %%
data
# Out:
#                            _id        yearOfRegistration Datasource  gender  \
# 0     5f751810edbeb111ec3ccdcd  18733               2015    Hotline  Female
# 1     5f751810edbeb111ec3ccdce  18734               2015    Hotline  Female
# 2     5f751810edbeb111ec3ccdcf  18735               2015    Hotline  Female
# 3     5f751810edbeb111ec3ccdd0  18736               2015    Hotline  Female
# 4     5f751810edbeb111ec3ccdd1  18737               2015    Hotline  Female
# ...                        ...    ...                ...        ...     ...
# 3632  5f751811edbeb111ec3cdbfd  48769               2018    Hotline    Male
# 3633  5f751811edbeb111ec3cdbfe  48770               2018    Hotline    Male
# 3634  5f751811edbeb111ec3cdbff  48771               2018    Hotline    Male
# 3635  5f751811edbeb111ec3cdc00  48772               2018    Hotline    Male
# 3636  5f7519ebe733c19559e77824    NaN                NaN        NaN     NaN
#
# ...

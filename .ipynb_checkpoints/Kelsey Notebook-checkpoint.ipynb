# %%
import requests
import pandas as pd
import io
from datetime import date
import numpy as np

# %%
us_human_trafficking_df = pd.read_csv("Data/Human_Trafficking_Offenses_and_Clearances_by_State_2014_to_2017_clean.csv")
us_human_trafficking_df.head()

new_us_human_trafficking_df = us_human_trafficking_df[['year', 'region_description', 'state', 'occurrence']]
new_us_human_trafficking_df.head()
# Out:
#    year region_description       state  occurrence
# 0  2014  Southwest/Pacific      Alaska          11
# 1  2014  Southwest/Pacific     Arizona          15
# 2  2014  Southwest/Pacific  California           0
# 3  2014   Rockies/Mid-West    Colorado          11
# 4  2014      Mideast South    Delaware           0

# %%
us_capitals_df = pd.read_csv("Data/us-state-capitals.csv")
us_capitals_df.rename(columns={"Name":"state"})
# Out:
#              state         Capital   latitude   longitude
# 0          Alabama      Montgomery  32.377716  -86.300568
# 1           Alaska          Juneau  58.301598 -134.420212
# 2          Arizona         Phoenix  33.448143 -112.096962
# 3         Arkansas     Little Rock  34.746613  -92.288986
# 4       California      Sacramento  38.576668 -121.493629
# 5         Colorado          Denver  39.739227 -104.984856
# 6      Connecticut        Hartford  41.764046  -72.682198
# 7         Delaware           Dover  39.157307  -75.519722
# 8           Hawaii        Honolulu  21.307442 -157.857376
# 9          Florida     Tallahassee  30.438118  -84.281296
# 10         Georgia     Atlanta<br>  33.749027  -84.388229
# 11           Idaho           Boise  43.617775 -116.199722
# 12        Illinois     Springfield  39.798363  -89.654961
# 13         Indiana    Indianapolis  39.768623  -86.162643
# 14            Iowa      Des Moines  41.591087  -93.603729
# ...
